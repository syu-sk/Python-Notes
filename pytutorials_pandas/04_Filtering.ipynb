# %% [markdown]
# **04: Filtering - Filtering Rows/Columns via Conditionals**

# %%
import pandas as pd

# %%
students = {
    'names': ['Tom', 'Bob', 'Jane', 'May'],
    'age': [9, 10, 10, 9],
    'subjects': ['Science', 'Arts', 'Hybrid', 'Arts'],
    'award winner': [True, False, False, True]
}

# %%
df = pd.DataFrame(students)
df
# Out:
#   names  age subjects  award winner
# 0   Tom    9  Science          True
# 1   Bob   10     Arts         False
# 2  Jane   10   Hybrid         False
# 3   May    9     Arts          True

# %% [markdown]
# ***
# Filtering:
# - Using conditionals to filter dataframes

# %%
df['subjects'] == 'Arts'
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: subjects, dtype: bool

# %% [markdown]
# ^A series is returned containing booleans based on whether the conditional is satisfied for each row

# %% [markdown]
# Filtering the DataFrame:
# - Using a conditional, minimise the DataFrame to one where all rows fulfill the conditional
# - Good practice to encase within parentheses for ease of reading

# %%
filt1 = (df['subjects'] == 'Arts')
#While there is no need to assign the conditional to a variable, it is good practice

# %%
df.loc[filt1]
# ==df[filt]. however loc provides more functionality as it also accepts a column input
# Out:
#   names  age subjects  award winner
# 1   Bob   10     Arts         False
# 3   May    9     Arts          True

# %% [markdown]
# 'And' and 'Or' in pandas:
# - Using built-in 'and' / 'or' will not work when filtering dataframes
# - For pandas, & = and, | = or
# - Note that &/| have to be outside parentheses, meaning additional conditionals have to be in parentheses alone
# - To invert the filter, use ~

# %%
filt2 = (df['subjects'] == 'Arts') & (df['award winner'] == True)
df.loc[filt2]
#when filtering, a dataframe instead of a series is returned
# Out:
#   names  age subjects  award winner
# 3   May    9     Arts          True

# %%
filt3 = (df['age'] == 10) | (df['subjects'] == 'Arts')
df.loc[filt3, 'names']
# Out:
# 1     Bob
# 2    Jane
# 3     May
# Name: names, dtype: object

# %%
df.loc[~filt3, 'names']
# Out:
# 0    Tom
# Name: names, dtype: object

# %% [markdown]
# ***
# Real Life Section:
# - Flexible Filtering of Salaries (>80000 yearly)
# - Flexible Filtering of Coding Experience (filtering out NaN responses)
# - Filtering by list of values
# - Filtering Strings
# - When passing a filter, it is also possible to pass methods which work on the datatype returned (.head, .columns etc.)

# %%
response_df = pd.read_csv('data.csv')
pd.set_option('display.max_columns', 114)

# %%
response_df.dtypes
#select a column with 'float64' to filter out values
# Out:
# ResponseId                          int64
# MainBranch                         object
# Age                                object
# Employment                         object
# RemoteWork                         object
# Check                              object
# CodingActivities                   object
# EdLevel                            object
# LearnCode                          object
# LearnCodeOnline                    object
# TechDoc                            object
# YearsCode                          object
# YearsCodePro                       object
# DevType                            object
# OrgSize                            object
# PurchaseInfluence                  object
# BuyNewTool                         object
# BuildvsBuy                         object
# TechEndorse                        object
# Country                            object
# Currency                           object
# CompTotal                         float64
# LanguageHaveWorkedWith             object
# LanguageWantToWorkWith             object
# LanguageAdmired                    object
# DatabaseHaveWorkedWith             object
# DatabaseWantToWorkWith             object
# DatabaseAdmired                    object
# PlatformHaveWorkedWith             object
# PlatformWantToWorkWith             object
# PlatformAdmired                    object
# WebframeHaveWorkedWith             object
# WebframeWantToWorkWith             object
# WebframeAdmired                    object
# EmbeddedHaveWorkedWith             object
# EmbeddedWantToWorkWith             object
# EmbeddedAdmired                    object
# MiscTechHaveWorkedWith             object
# MiscTechWantToWorkWith             object
# MiscTechAdmired                    object
# ToolsTechHaveWorkedWith            object
# ToolsTechWantToWorkWith            object
# ToolsTechAdmired                   object
# NEWCollabToolsHaveWorkedWith       object
# NEWCollabToolsWantToWorkWith       object
# NEWCollabToolsAdmired              object
# OpSysPersonal use                  object
# OpSysProfessional use              object
# OfficeStackAsyncHaveWorkedWith     object
# OfficeStackAsyncWantToWorkWith     object
# OfficeStackAsyncAdmired            object
# OfficeStackSyncHaveWorkedWith      object
# OfficeStackSyncWantToWorkWith      object
# OfficeStackSyncAdmired             object
# AISearchDevHaveWorkedWith          object
# AISearchDevWantToWorkWith          object
# AISearchDevAdmired                 object
# NEWSOSites                         object
# SOVisitFreq                        object
# SOAccount                          object
# SOPartFreq                         object
# SOHow                              object
# SOComm                             object
# AISelect                           object
# AISent                             object
# AIBen                              object
# AIAcc                              object
# AIComplex                          object
# AIToolCurrently Using              object
# AIToolInterested in Using          object
# AIToolNot interested in Using      object
# AINextMuch more integrated         object
# AINextNo change                    object
# AINextMore integrated              object
# AINextLess integrated              object
# AINextMuch less integrated         object
# AIThreat                           object
# AIEthics                           object
# AIChallenges                       object
# TBranch                            object
# ICorPM                             object
# WorkExp                           float64
# Knowledge_1                        object
# Knowledge_2                        object
# Knowledge_3                        object
# Knowledge_4                        object
# Knowledge_5                        object
# Knowledge_6                        object
# Knowledge_7                        object
# Knowledge_8                        object
# Knowledge_9                        object
# Frequency_1                        object
# Frequency_2                        object
# Frequency_3                        object
# TimeSearching                      object
# TimeAnswering                      object
# Frustration                        object
# ProfessionalTech                   object
# ProfessionalCloud                  object
# ProfessionalQuestion               object
# Industry                           object
# JobSatPoints_1                    float64
# JobSatPoints_4                    float64
# JobSatPoints_5                    float64
# JobSatPoints_6                    float64
# JobSatPoints_7                    float64
# JobSatPoints_8                    float64
# JobSatPoints_9                    float64
# JobSatPoints_10                   float64
# JobSatPoints_11                   float64
# SurveyLength                       object
# SurveyEase                         object
# ConvertedCompYearly               float64
# JobSat                            float64
# dtype: object

# %% [markdown]
# Here, 'CompTotal' which represents the total salary of the respondent will be filtered. Its datatype is float64 i.e a float

# %%
sal_filt = (response_df['CompTotal'] > 80000)
response_df.loc[sal_filt].head(3)
#filters salaries of >80000.
# Out:
#      ResponseId                      MainBranch              Age  \
# 72           73  I am a developer by profession  18-24 years old
# 379         380  I am a developer by profession  35-44 years old
# 389         390  I am a developer by profession  25-34 years old
#
#                                             Employment  \
# 72   Employed, full-time;Student, full-time;Indepen...
# 379                                Employed, full-time
# 389             Employed, full-time;Student, part-time
#
#                                RemoteWork   Check  \
# 72   Hybrid (some remote, some in-person)  Apples
# 379                                Remote  Apples
# 389                                Remote  Apples
#
#                                       CodingActivities  \
# 72   Hobby;School or academic work;Professional dev...
# 379                     Hobby;Bootstrapping a business
# 389                      Hobby;School or academic work
#
#                                                EdLevel  \
# 72   Secondary school (e.g. American high school, G...
# 379    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 389  Some college/university study without earning ...
#
#                                              LearnCode  \
# 72   On the job training;Other online resources (e....
# 379  Books / Physical media;Other online resources ...
# 389  Books / Physical media;Colleague;On the job tr...
#
#                                        LearnCodeOnline  \
# 72   Technical documentation;Blogs;Written Tutorial...
# 379  Technical documentation;Books;Social Media;Wri...
# 389  Written Tutorials;Stack Overflow;Coding sessio...
#
#                                                TechDoc YearsCode YearsCodePro  \
# 72   API document(s) and/or SDK document(s);User gu...         3            1
# 379             API document(s) and/or SDK document(s)        15            6
# 389                                                NaN         7            7
#
#                                            DevType               OrgSize  \
# 72   Data scientist or machine learning specialist  100 to 499 employees
# 379  Data scientist or machine learning specialist    20 to 99 employees
# 389                                        Student    10 to 19 employees
#
#                     PurchaseInfluence  \
# 72              I have some influence
# 379  I have a great deal of influence
# 389             I have some influence
#
#                                             BuyNewTool  \
# 72   Start a free trial;Ask developers I know/work ...
# 379  Ask developers I know/work with;Research compa...
# 389                    Ask developers I know/work with
#
#                                             BuildvsBuy  \
# 72   Is ready-to-go but also customizable for growt...
# 379  Is ready-to-go but also customizable for growt...
# 389  Is set up to be customized and needs to be eng...
#
#                                            TechEndorse  \
# 72   APIs;Customization;Integrated developer commun...
# 379           APIs;Connected to an open source project
# 389                                      Customization
#
#                       Country                   Currency  CompTotal  \
# 72                   Pakistan       PKR\tPakistani rupee  2040000.0
# 379                    Turkey          EUR European Euro    85000.0
# 389  United States of America  USD\tUnited States dollar   110000.0
#
#                                 LanguageHaveWorkedWith  \
# 72   Assembly;Bash/Shell (all shells);C;C++;HTML/CS...
# 379             JavaScript;Julia;Python;SQL;TypeScript
# 389          HTML/CSS;JavaScript;Python;SQL;TypeScript
#
#                        LanguageWantToWorkWith  \
# 72                              C#;Rust;Scala
# 379  Go;JavaScript;Python;Rust;SQL;TypeScript
# 389                             Go;Rust;Swift
#
#                       LanguageAdmired    DatabaseHaveWorkedWith  \
# 72                                NaN      MongoDB;MySQL;SQLite
# 379  JavaScript;Python;SQL;TypeScript  DuckDB;PostgreSQL;SQLite
# 389                               NaN      IBM DB2;MySQL;SQLite
#
#                                 DatabaseWantToWorkWith  \
# 72   BigQuery;Cassandra;Databricks SQL;Elasticsearc...
# 379                Clickhouse;DuckDB;PostgreSQL;SQLite
# 389                Cassandra;MariaDB;MongoDB;Snowflake
#
#               DatabaseAdmired  \
# 72                        NaN
# 379  DuckDB;PostgreSQL;SQLite
# 389                       NaN
#
#                                 PlatformHaveWorkedWith  \
# 72                              Microsoft Azure;VMware
# 379  Amazon Web Services (AWS);Cloudflare;Digital O...
# 389                          Amazon Web Services (AWS)
#
#                                 PlatformWantToWorkWith  \
# 72   Amazon Web Services (AWS);Databricks;Google Cloud
# 379  Amazon Web Services (AWS);Cloudflare;Google Cl...
# 389                                                NaN
#
#                                   PlatformAdmired  \
# 72                                            NaN
# 379  Amazon Web Services (AWS);Cloudflare;Hetzner
# 389                                           NaN
#
#                                 WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 72   Angular;AngularJS;Express;FastAPI;Flask;jQuery...                 Django
# 379                               Next.js;React;Vue.js          Svelte;Vue.js
# 389                       FastAPI;Flask;Node.js;Vue.js                    NaN
#
#     WebframeAdmired EmbeddedHaveWorkedWith EmbeddedWantToWorkWith  \
# 72              NaN                  CMake                    NaN
# 379          Vue.js                    NaN                    NaN
# 389             NaN    Arduino;Rasberry Pi                    NaN
#
#     EmbeddedAdmired                             MiscTechHaveWorkedWith  \
# 72              NaN  Apache Kafka;Apache Spark;CUDA;Hadoop;Hugging ...
# 379             NaN   JAX;NumPy;Pandas;Ruff;Scikit-Learn;Torch/PyTorch
# 389             NaN                                                NaN
#
#                                MiscTechWantToWorkWith  \
# 72               CUDA;mlflow;TensorFlow;Torch/PyTorch
# 379  JAX;NumPy;Pandas;Ruff;Scikit-Learn;Torch/PyTorch
# 389                                               NaN
#
#                                       MiscTechAdmired  \
# 72                      CUDA;TensorFlow;Torch/PyTorch
# 379  JAX;NumPy;Pandas;Ruff;Scikit-Learn;Torch/PyTorch
# 389                                               NaN
#
#            ToolsTechHaveWorkedWith ToolsTechWantToWorkWith ToolsTechAdmired  \
# 72             Docker;Homebrew;Pip                  Docker           Docker
# 379              Ansible;Make;Vite                    Vite             Vite
# 389  Homebrew;npm;Pip;Vite;Webpack                     NaN              NaN
#
#                           NEWCollabToolsHaveWorkedWith  \
# 72   IntelliJ IDEA;IPython;Jupyter Notebook/Jupyter...
# 379  IPython;Jupyter Notebook/JupyterLab;Visual Stu...
# 389                             Vim;Visual Studio Code
#
#                           NEWCollabToolsWantToWorkWith  \
# 72                                                 NaN
# 379  IPython;Jupyter Notebook/JupyterLab;Visual Stu...
# 389                                                NaN
#
#                                  NEWCollabToolsAdmired OpSysPersonal use  \
# 72                                                 NaN     MacOS;Windows
# 379  IPython;Jupyter Notebook/JupyterLab;Visual Stu...             MacOS
# 389                                                NaN     MacOS;Windows
#
#     OpSysProfessional use    OfficeStackAsyncHaveWorkedWith  \
# 72                    NaN  GitHub Discussions;Markdown File
# 379                 MacOS                               NaN
# 389                   NaN                   Confluence;Jira
#
#     OfficeStackAsyncWantToWorkWith OfficeStackAsyncAdmired  \
# 72                             NaN                     NaN
# 379                            NaN                     NaN
# 389                            NaN                     NaN
#
#                OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 72   Discord;Google Meet;Slack;Whatsapp;Zoom                           NaN
# 379                                      NaN                           NaN
# 389             Discord;Microsoft Teams;Zoom                           NaN
#
#     OfficeStackSyncAdmired                          AISearchDevHaveWorkedWith  \
# 72                     NaN  ChatGPT;GitHub Copilot;Google Gemini;Visual St...
# 379                    NaN                                            ChatGPT
# 389                    NaN                              ChatGPT;Google Gemini
#
#     AISearchDevWantToWorkWith AISearchDevAdmired  \
# 72                    Meta AI                NaN
# 379    ChatGPT;Claude;Meta AI            ChatGPT
# 389                       NaN                NaN
#
#                         NEWSOSites                      SOVisitFreq SOAccount  \
# 72   Stack Overflow;Stack Exchange             A few times per week       Yes
# 379                 Stack Overflow  A few times per month or weekly       Yes
# 389  Stack Overflow;Stack Exchange           Multiple times per day       Yes
#
#                               SOPartFreq  \
# 72   Less than once per month or monthly
# 379  Less than once per month or monthly
# 389      A few times per month or weekly
#
#                                                  SOHow          SOComm  \
# 72   Quickly finding code solutions;Finding reliabl...   Yes, somewhat
# 379                     Quickly finding code solutions  No, not at all
# 389                     Quickly finding code solutions   Yes, somewhat
#
#     AISelect          AISent  \
# 72       Yes  Very favorable
# 379      Yes  Very favorable
# 389      Yes  Very favorable
#
#                                                  AIBen  \
# 72   Increase productivity;Greater efficiency;Impro...
# 379           Increase productivity;Greater efficiency
# 389  Increase productivity;Greater efficiency;Speed...
#
#                           AIAcc  \
# 72               Somewhat trust
# 379              Somewhat trust
# 389  Neither trust nor distrust
#
#                                          AIComplex  \
# 72   Good, but not great at handling complex tasks
# 379                  Bad at handling complex tasks
# 389  Neither good or bad at handling complex tasks
#
#                                  AIToolCurrently Using  \
# 72   Learning about a codebase;Writing code;Documen...
# 379  Writing code;Documenting code;Debugging and ge...
# 389  Learning about a codebase;Writing code;Documen...
#
#                              AIToolInterested in Using  \
# 72   Project planning;Testing code;Committing and r...
# 379                          Learning about a codebase
# 389         Testing code;Committing and reviewing code
#
#                          AIToolNot interested in Using  \
# 72                                                 NaN
# 379  Project planning;Committing and reviewing code...
# 389  Project planning;Deployment and monitoring;Pre...
#
#                             AINextMuch more integrated AINextNo change  \
# 72   Learning about a codebase;Writing code;Documen...             NaN
# 379  Writing code;Documenting code;Debugging and ge...             NaN
# 389  Learning about a codebase;Debugging and gettin...    Writing code
#
#     AINextMore integrated AINextLess integrated AINextMuch less integrated  \
# 72                    NaN                   NaN                        NaN
# 379                   NaN                   NaN                        NaN
# 389      Documenting code                   NaN                        NaN
#
#     AIThreat                                           AIEthics  \
# 72        No  Circulating misinformation or disinformation;M...
# 379       No  Circulating misinformation or disinformation;M...
# 389       No  Circulating misinformation or disinformation;E...
#
#                                           AIChallenges TBranch  \
# 72   AI tools lack context of codebase,  internal a...     Yes
# 379  Don’t trust the output or answers;Lack of exec...     Yes
# 389  AI tools lack context of codebase,  internal a...     Yes
#
#                      ICorPM  WorkExp     Knowledge_1        Knowledge_2  \
# 72           People manager      3.0  Strongly agree  Strongly disagree
# 379  Individual contributor      7.0  Strongly agree     Strongly agree
# 389  Individual contributor      8.0        Disagree           Disagree
#
#         Knowledge_3     Knowledge_4     Knowledge_5  \
# 72   Strongly agree  Strongly agree  Strongly agree
# 379  Strongly agree  Strongly agree  Strongly agree
# 389           Agree  Strongly agree  Strongly agree
#
#                     Knowledge_6                 Knowledge_7     Knowledge_8  \
# 72               Strongly agree              Strongly agree  Strongly agree
# 379              Strongly agree              Strongly agree  Strongly agree
# 389  Neither agree nor disagree  Neither agree nor disagree  Strongly agree
#
#         Knowledge_9       Frequency_1        Frequency_2       Frequency_3  \
# 72   Strongly agree  1-2 times a week  6-10 times a week             Never
# 379  Strongly agree             Never              Never             Never
# 389           Agree  3-5 times a week   1-2 times a week  1-2 times a week
#
#                   TimeSearching               TimeAnswering  \
# 72          30-60 minutes a day        60-120 minutes a day
# 379  Less than 15 minutes a day  Less than 15 minutes a day
# 389        60-120 minutes a day  Less than 15 minutes a day
#
#                                            Frustration  \
# 72   Amount of technical debt;Number of software to...
# 379                 Complexity of tech stack for build
# 389   Number of software tools in use;Tracking my work
#
#                                       ProfessionalTech  \
# 72   DevOps function;Observability tools;Knowledge ...
# 379  Developer portal or other central places to fi...
# 389                      DevOps function;Microservices
#
#                       ProfessionalCloud      ProfessionalQuestion  \
# 72           Hybrid (on-prem and cloud)  AI-powered search (free)
# 379                             On-prem  AI-powered search (paid)
# 389  Cloud only (single or multi-cloud)  AI-powered search (free)
#
#                                  Industry  JobSatPoints_1  JobSatPoints_4  \
# 72                   Software Development            90.0            10.0
# 379  Computer Systems Design and Services             0.0             0.0
# 389       Transportation, or Supply Chain            10.0             0.0
#
#      JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# 72             75.0            65.0           100.0           100.0
# 379             0.0             0.0             0.0             0.0
# 389             0.0            20.0            30.0             5.0
#
#      JobSatPoints_9  JobSatPoints_10  JobSatPoints_11 SurveyLength SurveyEase  \
# 72            100.0             50.0             90.0     Too long       Easy
# 379             0.0              0.0              0.0     Too long  Difficult
# 389            20.0             10.0              5.0     Too long       Easy
#
#      ConvertedCompYearly  JobSat
# 72                7322.0    10.0
# 379              91295.0    10.0
# 389             110000.0    10.0

# %% [markdown]
# Filtering out NaN:

# %%
NaN_filt = (response_df['YearsCode'].notnull())
response_df.loc[NaN_filt, ['YearsCode', 'EdLevel']]
#filtering out NaN using .notnull()
# Out:
#       YearsCode                                            EdLevel
# 1            20       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            37    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3             4  Some college/university study without earning ...
# 4             9  Secondary school (e.g. American high school, G...
# 5            10                          Primary/elementary school
# ...         ...                                                ...
# 65428         4       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65431        38       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65432         5       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65434         9       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65435         5  Secondary school (e.g. American high school, G...
#
# [59869 rows x 2 columns]

# %% [markdown]
# Filtering by list of values:

# %%
edlevels = ['Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)']
ed_filt = response_df['EdLevel'].isin(edlevels)
#pandas isin method used to return a boolean for whether each value in the series is in the specified list
response_df.loc[ed_filt]
# Out:
#        ResponseId                                         MainBranch  \
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 9              10                     I am a developer by profession
# 10             11  I used to be a developer by profession, but no...
# 12             13                     I am a developer by profession
# ...           ...                                                ...
# 65417       65418                     I am a developer by profession
# 65428       65429                     I am a developer by profession
# 65431       65432                     I am a developer by profession
# 65432       65433                     I am a developer by profession
# 65434       65435                     I am a developer by profession
#
#                    Age                                         Employment  \
# 1      35-44 years old                                Employed, full-time
# 2      45-54 years old                                Employed, full-time
# 9      35-44 years old  Independent contractor, freelancer, or self-em...
# 10     35-44 years old                                Employed, full-time
# 12     35-44 years old                                Employed, full-time
# ...                ...                                                ...
# 65417  25-34 years old                                Employed, full-time
# 65428  25-34 years old                                Employed, full-time
# 65431  45-54 years old                                Employed, full-time
# 65432  18-24 years old                                Employed, full-time
# 65434  25-34 years old                                Employed, full-time
#
#                                  RemoteWork   Check  \
# 1                                    Remote  Apples
# 2                                    Remote  Apples
# 9                                    Remote  Apples
# 10                                   Remote  Apples
# 12     Hybrid (some remote, some in-person)  Apples
# ...                                     ...     ...
# 65417  Hybrid (some remote, some in-person)  Apples
# 65428                                Remote  Apples
# 65431  Hybrid (some remote, some in-person)  Apples
# 65432                                Remote  Apples
# 65434                             In-person  Apples
#
#                                         CodingActivities  \
# 1      Hobby;Contribute to open-source projects;Other...
# 2      Hobby;Contribute to open-source projects;Other...
# 9                               Bootstrapping a business
# 10              Hobby;Contribute to open-source projects
# 12     Hobby;Contribute to open-source projects;Profe...
# ...                                                  ...
# 65417  Hobby;Contribute to open-source projects;Boots...
# 65428  Hobby;Contribute to open-source projects;Profe...
# 65431  Hobby;Contribute to open-source projects;Profe...
# 65432                      Hobby;School or academic work
# 65434                                              Hobby
#
#                                                EdLevel  \
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 65417     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65428     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65431     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65432     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65434     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 1      Books / Physical media;Colleague;On the job tr...
# 2      Books / Physical media;Colleague;On the job tr...
# 9      On the job training;Other online resources (e....
# 10     Books / Physical media;Other online resources ...
# 12     Books / Physical media;On the job training;Sch...
# ...                                                  ...
# 65417                                    Coding Bootcamp
# 65428  Books / Physical media;Colleague;Other online ...
# 65431  Books / Physical media;Colleague;On the job tr...
# 65432  On the job training;School (i.e., University, ...
# 65434  Other online resources (e.g., videos, blogs, f...
#
#                                          LearnCodeOnline  \
# 1      Technical documentation;Blogs;Books;Written Tu...
# 2      Technical documentation;Blogs;Books;Written Tu...
# 9      Technical documentation;Blogs;Written Tutorial...
# 10     Technical documentation;Books;Written Tutorial...
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428  Technical documentation;Books;Interactive tuto...
# 65431  Technical documentation;Blogs;Books;Written Tu...
# 65432                                                NaN
# 65434  Technical documentation;Stack Overflow;Social ...
#
#                                                  TechDoc YearsCode  \
# 1      API document(s) and/or SDK document(s);User gu...        20
# 2      API document(s) and/or SDK document(s);User gu...        37
# 9      Traditional public search engine;AI-powered se...        15
# 10     API document(s) and/or SDK document(s);User gu...        20
# 12                                                   NaN        20
# ...                                                  ...       ...
# 65417                                                NaN         8
# 65428  API document(s) and/or SDK document(s);User gu...         4
# 65431  API document(s) and/or SDK document(s);User gu...        38
# 65432                                                NaN         5
# 65434  API document(s) and/or SDK document(s);AI-powe...         9
#
#       YearsCodePro                DevType                   OrgSize  \
# 1               17  Developer, full-stack                       NaN
# 2               27   Developer Experience                       NaN
# 9               11  Developer, full-stack                       NaN
# 10             NaN        Project manager                       NaN
# 12              12    Developer, back-end                       NaN
# ...            ...                    ...                       ...
# 65417            6  Developer, full-stack  1,000 to 4,999 employees
# 65428            7    Developer, back-end  1,000 to 4,999 employees
# 65431           24  Developer, full-stack        20 to 99 employees
# 65432            3             Blockchain          2 to 9 employees
# 65434            5      Developer, mobile  1,000 to 4,999 employees
#
#                    PurchaseInfluence  \
# 1                                NaN
# 2                                NaN
# 9                                NaN
# 10                               NaN
# 12                               NaN
# ...                              ...
# 65417          I have some influence
# 65428          I have some influence
# 65431          I have some influence
# 65432          I have some influence
# 65434  I have little or no influence
#
#                                               BuyNewTool  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428  Start a free trial;Ask developers I know/work ...
# 65431  Start a free trial;Ask developers I know/work ...
# 65432  Ask developers I know/work with;Ask a generati...
# 65434  Ask developers I know/work with;Ask a generati...
#
#                                               BuildvsBuy  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  Is ready-to-go but also customizable for growt...
# 65432  Is ready-to-go but also customizable for growt...
# 65434                                                NaN
#
#                                              TechEndorse  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428  Integrated developer community;Frequent update...
# 65431  APIs;Customization;Reputation for quality and ...
# 65432  APIs;Integrated developer community;Quality su...
# 65434                                                NaN
#
#                                                  Country           Currency  \
# 1      United Kingdom of Great Britain and Northern I...                NaN
# 2      United Kingdom of Great Britain and Northern I...                NaN
# 9                                                 Serbia                NaN
# 10                              United States of America                NaN
# 12                              United States of America                NaN
# ...                                                  ...                ...
# 65417                                                NaN                NaN
# 65428                                              India  INR\tIndian rupee
# 65431                                            Belgium  EUR European Euro
# 65432                                                NaN                NaN
# 65434                                                NaN                NaN
#
#        CompTotal                             LanguageHaveWorkedWith  \
# 1            NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2            NaN                                                 C#
# 9            NaN                     HTML/CSS;JavaScript;TypeScript
# 10           NaN                             JavaScript;Python;Ruby
# 12           NaN  Bash/Shell (all shells);C#;JavaScript;PowerShe...
# ...          ...                                                ...
# 65417        NaN                                                NaN
# 65428        NaN                                                NaN
# 65431    55000.0  Bash/Shell (all shells);C;C#;C++;Delphi;Groovy...
# 65432        NaN                                                NaN
# 65434        NaN                                                NaN
#
#                                   LanguageWantToWorkWith  \
# 1      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                     C#
# 9                         HTML/CSS;JavaScript;TypeScript
# 10                C#;Crystal;Java;JavaScript;Python;Ruby
# 12                Bash/Shell (all shells);JavaScript;VBA
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  Bash/Shell (all shells);C#;Go;HTML/CSS;Java;Ja...
# 65432                                                NaN
# 65434                                                NaN
#
#                                          LanguageAdmired  \
# 1      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                     C#
# 9                         HTML/CSS;JavaScript;TypeScript
# 10                                JavaScript;Python;Ruby
# 12                Bash/Shell (all shells);JavaScript;VBA
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 65432                                                NaN
# 65434                                                NaN
#
#                                   DatabaseHaveWorkedWith  \
# 1                            Dynamodb;MongoDB;PostgreSQL
# 2                             Firebase Realtime Database
# 9                         MongoDB;MySQL;PostgreSQL;Redis
# 10               Elasticsearch;MongoDB;PostgreSQL;SQLite
# 12                                                 MySQL
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  Couch DB;H2;Microsoft SQL Server;MySQL;Oracle;...
# 65432                                                NaN
# 65434                                                NaN
#
#                         DatabaseWantToWorkWith  \
# 1                                   PostgreSQL
# 2                   Firebase Realtime Database
# 9               MongoDB;MySQL;PostgreSQL;Redis
# 10     Elasticsearch;MongoDB;PostgreSQL;SQLite
# 12                                       MySQL
# ...                                        ...
# 65417                                      NaN
# 65428                                      NaN
# 65431           Elasticsearch;PostgreSQL;Redis
# 65432                                      NaN
# 65434                                      NaN
#
#                                DatabaseAdmired  \
# 1                                   PostgreSQL
# 2                   Firebase Realtime Database
# 9               MongoDB;MySQL;PostgreSQL;Redis
# 10     Elasticsearch;MongoDB;PostgreSQL;SQLite
# 12                                       MySQL
# ...                                        ...
# 65417                                      NaN
# 65428                                      NaN
# 65431                               PostgreSQL
# 65432                                      NaN
# 65434                                      NaN
#
#                                   PlatformHaveWorkedWith  \
# 1               Amazon Web Services (AWS);Heroku;Netlify
# 2                                           Google Cloud
# 9      Amazon Web Services (AWS);Digital Ocean;Fireba...
# 10                Amazon Web Services (AWS);Google Cloud
# 12     Amazon Web Services (AWS);Google Cloud;Hetzner...
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431                                    Microsoft Azure
# 65432                                                NaN
# 65434                                                NaN
#
#                                   PlatformWantToWorkWith  \
# 1               Amazon Web Services (AWS);Heroku;Netlify
# 2                                           Google Cloud
# 9      Amazon Web Services (AWS);Digital Ocean;Fireba...
# 10                                          Google Cloud
# 12                                        Hetzner;VMware
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  Amazon Web Services (AWS);Firebase;Microsoft A...
# 65432                                                NaN
# 65434                                                NaN
#
#                                          PlatformAdmired  \
# 1               Amazon Web Services (AWS);Heroku;Netlify
# 2                                           Google Cloud
# 9      Amazon Web Services (AWS);Digital Ocean;Fireba...
# 10                                          Google Cloud
# 12                                        Hetzner;VMware
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431                                    Microsoft Azure
# 65432                                                NaN
# 65434                                                NaN
#
#                                   WebframeHaveWorkedWith  \
# 1                          Express;Next.js;Node.js;React
# 2                                           ASP.NET CORE
# 9                          Express;Next.js;Node.js;React
# 10                           Node.js;React;Ruby on Rails
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  Angular;AngularJS;ASP.NET;ASP.NET CORE;Drupal;...
# 65432                                                NaN
# 65434                                                NaN
#
#                                  WebframeWantToWorkWith  \
# 1                      Express;Htmx;Node.js;React;Remix
# 2                                          ASP.NET CORE
# 9                         Express;Next.js;Node.js;React
# 10                   Django;Node.js;React;Ruby on Rails
# 12                                                  NaN
# ...                                                 ...
# 65417                                               NaN
# 65428                                               NaN
# 65431  Angular;ASP.NET;ASP.NET CORE;Node.js;Spring Boot
# 65432                                               NaN
# 65434                                               NaN
#
#                                         WebframeAdmired  \
# 1                                 Express;Node.js;React
# 2                                          ASP.NET CORE
# 9                         Express;Next.js;Node.js;React
# 10                          Node.js;React;Ruby on Rails
# 12                                                  NaN
# ...                                                 ...
# 65417                                               NaN
# 65428                                               NaN
# 65431  Angular;ASP.NET;ASP.NET CORE;Node.js;Spring Boot
# 65432                                               NaN
# 65434                                               NaN
#
#       EmbeddedHaveWorkedWith EmbeddedWantToWorkWith EmbeddedAdmired  \
# 1                        NaN                    NaN             NaN
# 2                Rasberry Pi            Rasberry Pi     Rasberry Pi
# 9                        NaN                    NaN             NaN
# 10                       NaN                    NaN             NaN
# 12                       NaN                    NaN             NaN
# ...                      ...                    ...             ...
# 65417                    NaN                    NaN             NaN
# 65428                    NaN                    NaN             NaN
# 65431                    NaN                    NaN             NaN
# 65432                    NaN                    NaN             NaN
# 65434                    NaN                    NaN             NaN
#
#                                   MiscTechHaveWorkedWith  \
# 1                                                    NaN
# 2        .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 9                                                    NaN
# 10                                                   NaN
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  .NET (5+) ;.NET Framework (1.0 - 4.8);Cordova;...
# 65432                                                NaN
# 65434                                                NaN
#
#                                   MiscTechWantToWorkWith  \
# 1                                                    NaN
# 2        .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 9                                                    NaN
# 10                                                   NaN
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  .NET (5+) ;.NET Framework (1.0 - 4.8);Quarkus;...
# 65432                                                NaN
# 65434                                                NaN
#
#                                          MiscTechAdmired  \
# 1                                                    NaN
# 2        .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 9                                                    NaN
# 10                                                   NaN
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  .NET (5+) ;.NET Framework (1.0 - 4.8);Spring F...
# 65432                                                NaN
# 65434                                                NaN
#
#                                  ToolsTechHaveWorkedWith  \
# 1            Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                                MSBuild
# 9                                            npm;Webpack
# 10                             Ansible;Docker;Kubernetes
# 12     Ansible;Chocolatey;Docker;Make;NuGet;Pacman;Pi...
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  Chocolatey;Docker;Gradle;Homebrew;Kubernetes;n...
# 65432                                                NaN
# 65434                                                NaN
#
#                                  ToolsTechWantToWorkWith  \
# 1            Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                                MSBuild
# 9                                            npm;Webpack
# 10                             Ansible;Docker;Kubernetes
# 12                                 Ansible;Docker;Pacman
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  Ansible;Chocolatey;Docker;Gradle;Homebrew;Kube...
# 65432                                                NaN
# 65434                                                NaN
#
#                                         ToolsTechAdmired  \
# 1            Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                                MSBuild
# 9                                            npm;Webpack
# 10                             Ansible;Docker;Kubernetes
# 12                                 Ansible;Docker;Pacman
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  Chocolatey;Docker;Gradle;Homebrew;Kubernetes;n...
# 65432                                                NaN
# 65434                                                NaN
#
#                             NEWCollabToolsHaveWorkedWith  \
# 1                    PyCharm;Visual Studio Code;WebStorm
# 2                                          Visual Studio
# 9                                     Visual Studio Code
# 10                                    Visual Studio Code
# 12                      Notepad++;Vim;Visual Studio Code
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  DataGrip;IntelliJ IDEA;PyCharm;Rider;Sublime T...
# 65432                                                NaN
# 65434                                                NaN
#
#                             NEWCollabToolsWantToWorkWith  \
# 1                    PyCharm;Visual Studio Code;WebStorm
# 2                                          Visual Studio
# 9                                     Visual Studio Code
# 10                                    Visual Studio Code
# 12               Neovim;Notepad++;Vim;Visual Studio Code
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  DataGrip;Fleet;IntelliJ IDEA;PyCharm;Rider;Sub...
# 65432                                                NaN
# 65434                                                NaN
#
#                                    NEWCollabToolsAdmired  \
# 1                    PyCharm;Visual Studio Code;WebStorm
# 2                                          Visual Studio
# 9                                     Visual Studio Code
# 10                                    Visual Studio Code
# 12                      Notepad++;Vim;Visual Studio Code
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  DataGrip;IntelliJ IDEA;PyCharm;Rider;Sublime T...
# 65432                                                NaN
# 65434                                                NaN
#
#                                        OpSysPersonal use  \
# 1                                          MacOS;Windows
# 2                                                Windows
# 9                                                Windows
# 10             Windows;Windows Subsystem for Linux (WSL)
# 12             Windows;Windows Subsystem for Linux (WSL)
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  Cygwin;Debian;iOS;iPadOS;MacOS;Ubuntu;Windows;...
# 65432                                                NaN
# 65434                                                NaN
#
#                                    OpSysProfessional use  \
# 1                                                  MacOS
# 2                                                Windows
# 9                                                Windows
# 10                                               Windows
# 12                     Windows Subsystem for Linux (WSL)
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431  Debian;iOS;iPadOS;MacOS;Other Linux-based;Ubun...
# 65432                                                NaN
# 65434                                                NaN
#
#                          OfficeStackAsyncHaveWorkedWith  \
# 1                                                   NaN
# 2                                                   NaN
# 9                                                  Jira
# 10        Confluence;GitHub Discussions;Jira;Smartsheet
# 12                                Doxygen;Jira;Obsidian
# ...                                                 ...
# 65417                                               NaN
# 65428                                               NaN
# 65431  Azure Devops;Confluence;Jira;Markdown File;Wikis
# 65432                                               NaN
# 65434                                               NaN
#
#                          OfficeStackAsyncWantToWorkWith  \
# 1                                                   NaN
# 2                                                   NaN
# 9                                                  Jira
# 10                   Confluence;GitHub Discussions;Jira
# 12                                                 Jira
# ...                                                 ...
# 65417                                               NaN
# 65428                                               NaN
# 65431  Azure Devops;Confluence;Jira;Markdown File;Wikis
# 65432                                               NaN
# 65434                                               NaN
#
#                                 OfficeStackAsyncAdmired  \
# 1                                                   NaN
# 2                                                   NaN
# 9                                                  Jira
# 10                   Confluence;GitHub Discussions;Jira
# 12                                                 Jira
# ...                                                 ...
# 65417                                               NaN
# 65428                                               NaN
# 65431  Azure Devops;Confluence;Jira;Markdown File;Wikis
# 65432                                               NaN
# 65434                                               NaN
#
#                         OfficeStackSyncHaveWorkedWith  \
# 1                               Microsoft Teams;Slack
# 2        Google Chat;Google Meet;Microsoft Teams;Zoom
# 9                     Discord;Google Meet;Skype;Slack
# 10     Discord;Google Meet;Microsoft Teams;Slack;Zoom
# 12                 Discord;Microsoft Teams;Slack;Zoom
# ...                                               ...
# 65417                                             NaN
# 65428                                             NaN
# 65431                      Mattermost;Microsoft Teams
# 65432                                             NaN
# 65434                                             NaN
#
#                         OfficeStackSyncWantToWorkWith  \
# 1                                               Slack
# 2                        Google Chat;Google Meet;Zoom
# 9                     Discord;Google Meet;Skype;Slack
# 10     Discord;Google Meet;Microsoft Teams;Slack;Zoom
# 12                            Discord;Microsoft Teams
# ...                                               ...
# 65417                                             NaN
# 65428                                             NaN
# 65431                                      Mattermost
# 65432                                             NaN
# 65434                                             NaN
#
#                                OfficeStackSyncAdmired  \
# 1                                               Slack
# 2                        Google Chat;Google Meet;Zoom
# 9                     Discord;Google Meet;Skype;Slack
# 10     Discord;Google Meet;Microsoft Teams;Slack;Zoom
# 12                            Discord;Microsoft Teams
# ...                                               ...
# 65417                                             NaN
# 65428                                             NaN
# 65431                                      Mattermost
# 65432                                             NaN
# 65434                                             NaN
#
#                                AISearchDevHaveWorkedWith  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                  ChatGPT;Google Gemini
# 10     ChatGPT;GitHub Copilot;Google Gemini;Meta AI;V...
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431                                                NaN
# 65432                                                NaN
# 65434                                                NaN
#
#                                AISearchDevWantToWorkWith  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                  ChatGPT;Google Gemini
# 10     GitHub Copilot;Google Gemini;Visual Studio Int...
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431                                                NaN
# 65432                                                NaN
# 65434                                                NaN
#
#                                       AISearchDevAdmired  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                  ChatGPT;Google Gemini
# 10     GitHub Copilot;Google Gemini;Visual Studio Int...
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431                                                NaN
# 65432                                                NaN
# 65434                                                NaN
#
#                                               NEWSOSites  \
# 1      Stack Overflow for Teams (private knowledge sh...
# 2      Stack Overflow;Stack Exchange;Stack Overflow B...
# 9                                         Stack Overflow
# 10     Stack Overflow for Teams (private knowledge sh...
# 12                         Stack Overflow;Stack Exchange
# ...                                                  ...
# 65417                                                NaN
# 65428                      Stack Overflow;Stack Exchange
# 65431                      Stack Overflow;Stack Exchange
# 65432                                                NaN
# 65434                                                NaN
#
#                            SOVisitFreq SOAccount  \
# 1               Multiple times per day       Yes
# 2               Multiple times per day       Yes
# 9                 A few times per week       Yes
# 10                A few times per week       Yes
# 12              Multiple times per day       Yes
# ...                                ...       ...
# 65417                              NaN       NaN
# 65428  A few times per month or weekly        No
# 65431             A few times per week       Yes
# 65432                              NaN       NaN
# 65434                              NaN       NaN
#
#                                 SOPartFreq  \
# 1                   Multiple times per day
# 2                   Multiple times per day
# 9      Less than once per month or monthly
# 10     Less than once per month or monthly
# 12                    A few times per week
# ...                                    ...
# 65417                                  NaN
# 65428                                  NaN
# 65431  Less than once per month or monthly
# 65432                                  NaN
# 65434                                  NaN
#
#                                                    SOHow           SOComm  \
# 1      Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 2      Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 9                         Quickly finding code solutions    Yes, somewhat
# 10     Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 12     Showcase expertise with code solutions;Engage ...  Yes, definitely
# ...                                                  ...              ...
# 65417                                                NaN              NaN
# 65428  Quickly finding code solutions;Finding reliabl...          Neutral
# 65431  Quickly finding code solutions;Showcase expert...   No, not at all
# 65432                                                NaN              NaN
# 65434                                                NaN              NaN
#
#                       AISelect       AISent  \
# 1      No, and I don't plan to          NaN
# 2      No, and I don't plan to          NaN
# 9                          Yes  Indifferent
# 10                         Yes    Favorable
# 12     No, and I don't plan to          NaN
# ...                        ...          ...
# 65417                      Yes    Favorable
# 65428  No, and I don't plan to          NaN
# 65431   No, but I plan to soon    Favorable
# 65432                      Yes    Favorable
# 65434                      NaN          NaN
#
#                                                    AIBen  \
# 1                                                    NaN
# 2                                                    NaN
# 9                Increase productivity;Speed up learning
# 10     Increase productivity;Speed up learning;Improv...
# 12                                                   NaN
# ...                                                  ...
# 65417  Increase productivity;Speed up learning;Improv...
# 65428                                                NaN
# 65431                                                NaN
# 65432  Increase productivity;Greater efficiency;Speed...
# 65434                                                NaN
#
#                             AIAcc  \
# 1                             NaN
# 2                             NaN
# 9      Neither trust nor distrust
# 10              Somewhat distrust
# 12                            NaN
# ...                           ...
# 65417              Somewhat trust
# 65428                         NaN
# 65431                         NaN
# 65432  Neither trust nor distrust
# 65434                         NaN
#
#                                            AIComplex  \
# 1                                                NaN
# 2                                                NaN
# 9                      Bad at handling complex tasks
# 10     Neither good or bad at handling complex tasks
# 12                                               NaN
# ...                                              ...
# 65417  Good, but not great at handling complex tasks
# 65428                                            NaN
# 65431                                            NaN
# 65432  Good, but not great at handling complex tasks
# 65434                                            NaN
#
#                                    AIToolCurrently Using  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                     Search for answers
# 10     Learning about a codebase;Writing code;Documen...
# 12                                                   NaN
# ...                                                  ...
# 65417  Project planning;Writing code;Documenting code...
# 65428                                                NaN
# 65431                                                NaN
# 65432  Learning about a codebase;Project planning;Wri...
# 65434                                                NaN
#
#                                AIToolInterested in Using  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                                    NaN
# 10     Project planning;Testing code;Generating conte...
# 12                                                   NaN
# ...                                                  ...
# 65417  Learning about a codebase;Testing code;Committ...
# 65428                                                NaN
# 65431                                                NaN
# 65432  Debugging and getting help;Testing code;Deploy...
# 65434                                                NaN
#
#                            AIToolNot interested in Using  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                                    NaN
# 10     Committing and reviewing code;Deployment and m...
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431                                                NaN
# 65432                      Committing and reviewing code
# 65434                                                NaN
#
#                               AINextMuch more integrated  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 12                                                   NaN
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431                                                NaN
# 65432  Writing code;Search for answers;Generating con...
# 65434                                                NaN
#
#                                          AINextNo change  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                     Search for answers
# 10                                                   NaN
# 12                                                   NaN
# ...                                                  ...
# 65417  Writing code;Debugging and getting help;Search...
# 65428                                                NaN
# 65431                                                NaN
# 65432                                                NaN
# 65434                                                NaN
#
#                                    AINextMore integrated  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                                    NaN
# 10     Learning about a codebase;Writing code;Documen...
# 12                                                   NaN
# ...                                                  ...
# 65417  Project planning;Predictive analytics;Generati...
# 65428                                                NaN
# 65431                                                NaN
# 65432  Learning about a codebase;Project planning;Doc...
# 65434                                                NaN
#
#       AINextLess integrated AINextMuch less integrated      AIThreat  \
# 1                       NaN                        NaN           NaN
# 2                       NaN                        NaN           NaN
# 9                       NaN                        NaN  I'm not sure
# 10                      NaN                        NaN            No
# 12                      NaN                        NaN           NaN
# ...                     ...                        ...           ...
# 65417      Documenting code                        NaN            No
# 65428                   NaN                        NaN           NaN
# 65431                   NaN                        NaN  I'm not sure
# 65432                   NaN                        NaN            No
# 65434                   NaN                        NaN           NaN
#
#                                                 AIEthics  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                                    NaN
# 10     Circulating misinformation or disinformation;M...
# 12                                                   NaN
# ...                                                  ...
# 65417  Circulating misinformation or disinformation;M...
# 65428                                                NaN
# 65431  Circulating misinformation or disinformation;M...
# 65432       Circulating misinformation or disinformation
# 65434                                                NaN
#
#                                             AIChallenges TBranch  \
# 1                                                    NaN     Yes
# 2                                                    NaN      No
# 9                                                    NaN     NaN
# 10     Don’t trust the output or answers;AI tools lac...     Yes
# 12                                                   NaN     Yes
# ...                                                  ...     ...
# 65417  Don’t trust the output or answers;AI tools lac...     NaN
# 65428                                                NaN     NaN
# 65431  Don’t trust the output or answers;AI tools lac...     Yes
# 65432  AI tools lack context of codebase,  internal a...     NaN
# 65434                                                NaN     NaN
#
#                        ICorPM  WorkExp     Knowledge_1 Knowledge_2  \
# 1      Individual contributor     17.0           Agree    Disagree
# 2                         NaN      NaN             NaN         NaN
# 9                         NaN      NaN             NaN         NaN
# 10     Individual contributor     15.0  Strongly agree       Agree
# 12     Individual contributor     12.0  Strongly agree    Disagree
# ...                       ...      ...             ...         ...
# 65417                     NaN      NaN             NaN         NaN
# 65428                     NaN      NaN             NaN         NaN
# 65431  Individual contributor      NaN             NaN         NaN
# 65432                     NaN      NaN             NaN         NaN
# 65434                     NaN      NaN             NaN         NaN
#
#                       Knowledge_3 Knowledge_4 Knowledge_5  \
# 1                           Agree       Agree       Agree
# 2                             NaN         NaN         NaN
# 9                             NaN         NaN         NaN
# 10                 Strongly agree       Agree       Agree
# 12     Neither agree nor disagree       Agree       Agree
# ...                           ...         ...         ...
# 65417                         NaN         NaN         NaN
# 65428                         NaN         NaN         NaN
# 65431                         NaN         NaN         NaN
# 65432                         NaN         NaN         NaN
# 65434                         NaN         NaN         NaN
#
#                       Knowledge_6 Knowledge_7                 Knowledge_8  \
# 1      Neither agree nor disagree    Disagree                       Agree
# 2                             NaN         NaN                         NaN
# 9                             NaN         NaN                         NaN
# 10                 Strongly agree       Agree  Neither agree nor disagree
# 12              Strongly disagree       Agree                       Agree
# ...                           ...         ...                         ...
# 65417                         NaN         NaN                         NaN
# 65428                         NaN         NaN                         NaN
# 65431                         NaN         NaN                         NaN
# 65432                         NaN         NaN                         NaN
# 65434                         NaN         NaN                         NaN
#
#                       Knowledge_9       Frequency_1        Frequency_2  \
# 1                           Agree               NaN                NaN
# 2                             NaN               NaN                NaN
# 9                             NaN               NaN                NaN
# 10     Neither agree nor disagree  3-5 times a week  6-10 times a week
# 12              Strongly disagree  1-2 times a week   1-2 times a week
# ...                           ...               ...                ...
# 65417                         NaN               NaN                NaN
# 65428                         NaN               NaN                NaN
# 65431                         NaN               NaN                NaN
# 65432                         NaN               NaN                NaN
# 65434                         NaN               NaN                NaN
#
#              Frequency_3        TimeSearching         TimeAnswering  \
# 1                    NaN                  NaN                   NaN
# 2                    NaN                  NaN                   NaN
# 9                    NaN                  NaN                   NaN
# 10     6-10 times a week  30-60 minutes a day  60-120 minutes a day
# 12      1-2 times a week  30-60 minutes a day   15-30 minutes a day
# ...                  ...                  ...                   ...
# 65417                NaN                  NaN                   NaN
# 65428                NaN                  NaN                   NaN
# 65431                NaN                  NaN                   NaN
# 65432                NaN                  NaN                   NaN
# 65434                NaN                  NaN                   NaN
#
#                                              Frustration  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                                    NaN
# 10     Amount of technical debt;Number of software to...
# 12     Amount of technical debt;Complexity of tech st...
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431                                                NaN
# 65432                                                NaN
# 65434                                                NaN
#
#                                         ProfessionalTech  \
# 1                                                    NaN
# 2                                                    NaN
# 9                                                    NaN
# 10     DevOps function;Automated testing;Observabilit...
# 12                           Knowledge sharing community
# ...                                                  ...
# 65417                                                NaN
# 65428                                                NaN
# 65431                                                NaN
# 65432                                                NaN
# 65434                                                NaN
#
#                         ProfessionalCloud       ProfessionalQuestion  \
# 1                                     NaN                        NaN
# 2                                     NaN                        NaN
# 9                                     NaN                        NaN
# 10     Cloud only (single or multi-cloud)  Internal Developer portal
# 12             Hybrid (on-prem and cloud)                 A coworker
# ...                                   ...                        ...
# 65417                                 NaN                        NaN
# 65428                                 NaN                        NaN
# 65431                                 NaN                        NaN
# 65432                                 NaN                        NaN
# 65434                                 NaN                        NaN
#
#                    Industry  JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  \
# 1                       NaN             0.0             0.0             0.0
# 2                       NaN             NaN             NaN             NaN
# 9                       NaN             NaN             NaN             NaN
# 10               Healthcare            50.0             0.0             0.0
# 12     Software Development             0.0             0.0            30.0
# ...                     ...             ...             ...             ...
# 65417                   NaN             NaN             NaN             NaN
# 65428                   NaN             NaN             NaN             NaN
# 65431                   NaN             NaN             NaN             NaN
# 65432                   NaN             NaN             NaN             NaN
# 65434                   NaN             NaN             NaN             NaN
#
#        JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  \
# 1                 0.0             0.0             0.0             0.0
# 2                 NaN             NaN             NaN             NaN
# 9                 NaN             NaN             NaN             NaN
# 10               25.0            10.0             0.0            15.0
# 12               30.0             0.0             0.0            20.0
# ...               ...             ...             ...             ...
# 65417             NaN             NaN             NaN             NaN
# 65428             NaN             NaN             NaN             NaN
# 65431             NaN             NaN             NaN             NaN
# 65432             NaN             NaN             NaN             NaN
# 65434             NaN             NaN             NaN             NaN
#
#        JobSatPoints_10  JobSatPoints_11           SurveyLength SurveyEase  \
# 1                  0.0              0.0                    NaN        NaN
# 2                  NaN              NaN  Appropriate in length       Easy
# 9                  NaN              NaN               Too long       Easy
# 10                 0.0              0.0  Appropriate in length       Easy
# 12                10.0             10.0  Appropriate in length       Easy
# ...                ...              ...                    ...        ...
# 65417              NaN              NaN                    NaN        NaN
# 65428              NaN              NaN                    NaN        NaN
# 65431              NaN              NaN                    NaN        NaN
# 65432              NaN              NaN                    NaN        NaN
# 65434              NaN              NaN                    NaN        NaN
#
#        ConvertedCompYearly  JobSat
# 1                      NaN     NaN
# 2                      NaN     NaN
# 9                      NaN     NaN
# 10                     NaN     8.0
# 12                     NaN     8.0
# ...                    ...     ...
# 65417                  NaN     NaN
# 65428                  NaN     NaN
# 65431                  NaN     NaN
# 65432                  NaN     NaN
# 65434                  NaN     NaN
#
# [40499 rows x 114 columns]

# %% [markdown]
# Filtering Strings:
# - See CodingActivities. It is impractical to use conditionals to search for those doing coding for School or academic work for example, since there could be more than one answer
# - Thus it would be more convenient to filter by strings

# %%
activity_filt = response_df['CodingActivities'].str.contains('School', na=False)
#pandas .str.contains method returns a boolean on whether each value in the series contains the string
#na=False basically sets all NaN values to False
response_df[activity_filt]
# Out:
#        ResponseId                                         MainBranch  \
# 11             12                     I am a developer by profession
# 36             37                     I am a developer by profession
# 43             44                     I am a developer by profession
# 51             52                     I am a developer by profession
# 60             61                        I code primarily as a hobby
# ...           ...                                                ...
# 65375       65376                     I am a developer by profession
# 65402       65403  I am not primarily a developer, but I write co...
# 65404       65405  I am not primarily a developer, but I write co...
# 65405       65406                     I am a developer by profession
# 65432       65433                     I am a developer by profession
#
#                    Age                                         Employment  \
# 11     45-54 years old                                Employed, full-time
# 36     18-24 years old  Independent contractor, freelancer, or self-em...
# 43     35-44 years old             Employed, full-time;Student, full-time
# 51     18-24 years old             Student, full-time;Employed, part-time
# 60     18-24 years old             Student, full-time;Employed, part-time
# ...                ...                                                ...
# 65375  25-34 years old                                Employed, full-time
# 65402  25-34 years old                                Employed, full-time
# 65404  35-44 years old                                Employed, full-time
# 65405  35-44 years old                                Employed, full-time
# 65432  18-24 years old                                Employed, full-time
#
#                                  RemoteWork   Check  \
# 11                                In-person  Apples
# 36                                   Remote  Apples
# 43                                In-person  Apples
# 51     Hybrid (some remote, some in-person)  Apples
# 60     Hybrid (some remote, some in-person)  Apples
# ...                                     ...     ...
# 65375  Hybrid (some remote, some in-person)  Apples
# 65402                                Remote  Apples
# 65404  Hybrid (some remote, some in-person)  Apples
# 65405  Hybrid (some remote, some in-person)  Apples
# 65432                                Remote  Apples
#
#                                         CodingActivities  \
# 11                         Hobby;School or academic work
# 36     Contribute to open-source projects;Bootstrappi...
# 43                         Hobby;School or academic work
# 51     Hobby;School or academic work;Freelance/contra...
# 60     Hobby;Contribute to open-source projects;Schoo...
# ...                                                  ...
# 65375  Hobby;Contribute to open-source projects;Schoo...
# 65402  Hobby;Contribute to open-source projects;Schoo...
# 65404  Bootstrapping a business;School or academic wo...
# 65405  Hobby;School or academic work;Professional dev...
# 65432                      Hobby;School or academic work
#
#                                                  EdLevel  \
# 11        Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 36     Secondary school (e.g. American high school, G...
# 43       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 51     Secondary school (e.g. American high school, G...
# 60     Secondary school (e.g. American high school, G...
# ...                                                  ...
# 65375                                                NaN
# 65402       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65404     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 65405    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 11     Books / Physical media;School (i.e., Universit...
# 36               School (i.e., University, College, etc)
# 43     Books / Physical media;School (i.e., Universit...
# 51     Other online resources (e.g., videos, blogs, f...
# 60                                Books / Physical media
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404  Other online resources (e.g., videos, blogs, f...
# 65405  Books / Physical media;Colleague;On the job tr...
# 65432  On the job training;School (i.e., University, ...
#
#                                          LearnCodeOnline  \
# 11                                                   NaN
# 36                                                   NaN
# 43                                                   NaN
# 51     Technical documentation;Written Tutorials;Stac...
# 60                                                   NaN
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404  Technical documentation;Coding sessions (live ...
# 65405                                                NaN
# 65432                                                NaN
#
#                                                  TechDoc YearsCode  \
# 11                                                   NaN        30
# 36                                                   NaN         9
# 43                                                   NaN        22
# 51     API document(s) and/or SDK document(s);User gu...         8
# 60                                                   NaN         5
# ...                                                  ...       ...
# 65375                                                NaN       NaN
# 65402                                                NaN       NaN
# 65404  User guides or README files found in the sourc...         7
# 65405                                                NaN       NaN
# 65432                                                NaN         5
#
#       YearsCodePro                  DevType             OrgSize  \
# 11              25       Developer Advocate                 NaN
# 36               8                  Student                 NaN
# 43              14      Academic researcher                 NaN
# 51               3    Developer, full-stack                 NaN
# 60             NaN  Other (please specify):                 NaN
# ...            ...                      ...                 ...
# 65375          NaN                      NaN                 NaN
# 65402          NaN                      NaN                 NaN
# 65404            3      Academic researcher  20 to 99 employees
# 65405          NaN                      NaN                 NaN
# 65432            3               Blockchain    2 to 9 employees
#
#            PurchaseInfluence  \
# 11                       NaN
# 36                       NaN
# 43                       NaN
# 51                       NaN
# 60                       NaN
# ...                      ...
# 65375                    NaN
# 65402                    NaN
# 65404  I have some influence
# 65405                    NaN
# 65432  I have some influence
#
#                                               BuyNewTool  \
# 11                                                   NaN
# 36                                                   NaN
# 43                                                   NaN
# 51                                                   NaN
# 60                                                   NaN
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404  Ask developers I know/work with;Visit develope...
# 65405                                                NaN
# 65432  Ask developers I know/work with;Ask a generati...
#
#                                               BuildvsBuy  \
# 11                                                   NaN
# 36                                                   NaN
# 43                                                   NaN
# 51                                                   NaN
# 60                                                   NaN
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432  Is ready-to-go but also customizable for growt...
#
#                                              TechEndorse  \
# 11                                                   NaN
# 36                                                   NaN
# 43                                                   NaN
# 51                                                   NaN
# 60                                                   NaN
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432  APIs;Integrated developer community;Quality su...
#
#                         Country Currency  CompTotal  \
# 11                       Poland      NaN        NaN
# 36                      Austria      NaN        NaN
# 43                      Austria      NaN        NaN
# 51     United States of America      NaN        NaN
# 60                        Nepal      NaN        NaN
# ...                         ...      ...        ...
# 65375                       NaN      NaN        NaN
# 65402                       NaN      NaN        NaN
# 65404                       NaN      NaN        NaN
# 65405                       NaN      NaN        NaN
# 65432                       NaN      NaN        NaN
#
#                                   LanguageHaveWorkedWith  \
# 11     C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Power...
# 36             Bash/Shell (all shells);C#;Java;OCaml;SQL
# 43     Assembly;C#;C++;HTML/CSS;JavaScript;MATLAB;Pyt...
# 51     Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScr...
# 60     Assembly;C++;Go;HTML/CSS;JavaScript;Julia;Lisp...
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                  R
# 65405                                                NaN
# 65432                                                NaN
#
#                                   LanguageWantToWorkWith  \
# 11     C#;HTML/CSS;JavaScript;PowerShell;Rust;SQL;Typ...
# 36                      Bash/Shell (all shells);Java;SQL
# 43        Assembly;C#;C++;HTML/CSS;JavaScript;Python;SQL
# 51     Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScr...
# 60      Assembly;C++;Go;HTML/CSS;Julia;Lisp;Rust;SQL;Zig
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                     HTML/CSS;JavaScript;Python;SQL
# 65405                                                NaN
# 65432                                                NaN
#
#                                          LanguageAdmired  \
# 11      C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript
# 36                      Bash/Shell (all shells);Java;SQL
# 43        Assembly;C#;C++;HTML/CSS;JavaScript;Python;SQL
# 51     Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScr...
# 60          Assembly;C++;Go;HTML/CSS;Julia;Lisp;Rust;SQL
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                   DatabaseHaveWorkedWith  \
# 11     Microsoft Access;Microsoft SQL Server;PostgreS...
# 36                                              H2;MySQL
# 43                                  Microsoft SQL Server
# 51     BigQuery;Clickhouse;Cloud Firestore;Cosmos DB;...
# 60               Cloud Firestore;MySQL;PostgreSQL;SQLite
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                   DatabaseWantToWorkWith  \
# 11                Microsoft SQL Server;PostgreSQL;SQLite
# 36                                        H2;MySQL;Neo4J
# 43                                  Microsoft SQL Server
# 51     BigQuery;Clickhouse;Cloud Firestore;Microsoft ...
# 60                               MySQL;PostgreSQL;SQLite
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                          DatabaseAdmired  \
# 11                Microsoft SQL Server;PostgreSQL;SQLite
# 36                                              H2;MySQL
# 43                                  Microsoft SQL Server
# 51     BigQuery;Clickhouse;Cloud Firestore;Microsoft ...
# 60                               MySQL;PostgreSQL;SQLite
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                   PlatformHaveWorkedWith  \
# 11                                            Cloudflare
# 36        Google Cloud;Oracle Cloud Infrastructure (OCI)
# 43                                       Microsoft Azure
# 51     Cloudflare;Firebase;Google Cloud;Microsoft Azu...
# 60                                   Cloudflare;Firebase
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                   PlatformWantToWorkWith  \
# 11                                            Cloudflare
# 36        Google Cloud;Oracle Cloud Infrastructure (OCI)
# 43                                       Microsoft Azure
# 51     Amazon Web Services (AWS);Cloudflare;Digital O...
# 60                                   Cloudflare;Firebase
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                          PlatformAdmired  \
# 11                                            Cloudflare
# 36        Google Cloud;Oracle Cloud Infrastructure (OCI)
# 43                                       Microsoft Azure
# 51     Cloudflare;Firebase;Google Cloud;Microsoft Azu...
# 60                                   Cloudflare;Firebase
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                   WebframeHaveWorkedWith  \
# 11     ASP.NET;ASP.NET CORE;Express;jQuery;Node.js;React
# 36                      ASP.NET;ASP.NET CORE;Spring Boot
# 43                                  ASP.NET;ASP.NET CORE
# 51     Angular;ASP.NET;ASP.NET CORE;Node.js;React;Sol...
# 60                                     Htmx;jQuery;React
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                   WebframeWantToWorkWith  \
# 11     ASP.NET;ASP.NET CORE;Express;jQuery;Node.js;React
# 36                                           Spring Boot
# 43                                  ASP.NET;ASP.NET CORE
# 51     ASP.NET;ASP.NET CORE;Astro;FastAPI;Htmx;Node.j...
# 60                                                   NaN
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                          WebframeAdmired  \
# 11     ASP.NET;ASP.NET CORE;Express;jQuery;Node.js;React
# 36                                           Spring Boot
# 43                                  ASP.NET;ASP.NET CORE
# 51                 ASP.NET;ASP.NET CORE;Node.js;Solid.js
# 60                                                   NaN
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                EmbeddedHaveWorkedWith  \
# 11                                                NaN
# 36                                                NaN
# 43                                         CMake;MSVC
# 51                                       LLVM's Clang
# 60     Arduino;CMake;Cargo;GNU GCC;LLVM's Clang;QMake
# ...                                               ...
# 65375                                             NaN
# 65402                                             NaN
# 65404                                             NaN
# 65405                                             NaN
# 65432                                             NaN
#
#                          EmbeddedWantToWorkWith  \
# 11                                          NaN
# 36                                          NaN
# 43                                         MSVC
# 51             Arduino;LLVM's Clang;Rasberry Pi
# 60     Arduino;CMake;Cargo;GNU GCC;LLVM's Clang
# ...                                         ...
# 65375                                       NaN
# 65402                                       NaN
# 65404                                       NaN
# 65405                                       NaN
# 65432                                       NaN
#
#                                 EmbeddedAdmired  \
# 11                                          NaN
# 36                                          NaN
# 43                                         MSVC
# 51                                 LLVM's Clang
# 60     Arduino;CMake;Cargo;GNU GCC;LLVM's Clang
# ...                                         ...
# 65375                                       NaN
# 65402                                       NaN
# 65404                                       NaN
# 65405                                       NaN
# 65432                                       NaN
#
#                                   MiscTechHaveWorkedWith  \
# 11     .NET (5+) ;.NET Framework (1.0 - 4.8);RabbitMQ...
# 36     NumPy;Pandas;Scikit-Learn;Spring Framework;Tor...
# 43     .NET (5+) ;.NET Framework (1.0 - 4.8);CUDA;Dir...
# 51     .NET (5+) ;.NET Framework (1.0 - 4.8);Electron...
# 60                                      Opencv;OpenGL;Qt
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                          Tidyverse
# 65405                                                NaN
# 65432                                                NaN
#
#                                MiscTechWantToWorkWith  \
# 11     .NET (5+) ;.NET Framework (1.0 - 4.8);RabbitMQ
# 36                     Spring Framework;Torch/PyTorch
# 43               .NET (5+) ;CUDA;DirectX;NumPy;OpenGL
# 51                .NET (5+) ;CUDA;Tauri;Torch/PyTorch
# 60                              CUDA;Opencv;OpenGL;Qt
# ...                                               ...
# 65375                                             NaN
# 65402                                             NaN
# 65404  NumPy;Pandas;Scikit-Learn;TensorFlow;Tidyverse
# 65405                                             NaN
# 65432                                             NaN
#
#                                       MiscTechAdmired  \
# 11     .NET (5+) ;.NET Framework (1.0 - 4.8);RabbitMQ
# 36                     Spring Framework;Torch/PyTorch
# 43               .NET (5+) ;CUDA;DirectX;NumPy;OpenGL
# 51                                   .NET (5+) ;Tauri
# 60                                   Opencv;OpenGL;Qt
# ...                                               ...
# 65375                                             NaN
# 65402                                             NaN
# 65404                                       Tidyverse
# 65405                                             NaN
# 65432                                             NaN
#
#                                  ToolsTechHaveWorkedWith  \
# 11                               Docker;npm;Webpack;Yarn
# 36                  Gradle;Kubernetes;Maven (build tool)
# 43     Docker;MSBuild;NuGet;Pip;Unity 3D;Unreal Engin...
# 51     Docker;Make;MSBuild;Pip;pnpm;Unity 3D;Vite;Web...
# 60                         APT;Docker;Ninja;npm;Pip;Vite
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                  ToolsTechWantToWorkWith  \
# 11                               Docker;npm;Webpack;Yarn
# 36                         Kubernetes;Maven (build tool)
# 43     MSBuild;NuGet;Pip;Unity 3D;Unreal Engine;Visua...
# 51     Docker;MSBuild;Pip;pnpm;Unity 3D;Unreal Engine...
# 60                                                 Ninja
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                                         ToolsTechAdmired  \
# 11                               Docker;npm;Webpack;Yarn
# 36                         Kubernetes;Maven (build tool)
# 43     MSBuild;NuGet;Pip;Unity 3D;Unreal Engine;Visua...
# 51                 Docker;MSBuild;Pip;pnpm;Unity 3D;Vite
# 60                                                 Ninja
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                                                NaN
#
#                             NEWCollabToolsHaveWorkedWith  \
# 11     Android Studio;IntelliJ IDEA;Netbeans;Notepad+...
# 36     Eclipse;IPython;Jupyter Notebook/JupyterLab;No...
# 43     Jupyter Notebook/JupyterLab;Notepad++;Visual S...
# 51                      Visual Studio;Visual Studio Code
# 60                                  CLion;Qt Creator;Vim
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                            RStudio
# 65405                                                NaN
# 65432                                                NaN
#
#                      NEWCollabToolsWantToWorkWith  \
# 11     Notepad++;Visual Studio;Visual Studio Code
# 36                                        Eclipse
# 43     Notepad++;Visual Studio;Visual Studio Code
# 51                   Helix;Vim;Visual Studio Code
# 60                                      CLion;Vim
# ...                                           ...
# 65375                                         NaN
# 65402                                         NaN
# 65404    RStudio;Visual Studio;Visual Studio Code
# 65405                                         NaN
# 65432                                         NaN
#
#                             NEWCollabToolsAdmired  \
# 11     Notepad++;Visual Studio;Visual Studio Code
# 36                                        Eclipse
# 43     Notepad++;Visual Studio;Visual Studio Code
# 51                             Visual Studio Code
# 60                                      CLion;Vim
# ...                                           ...
# 65375                                         NaN
# 65402                                         NaN
# 65404                                     RStudio
# 65405                                         NaN
# 65432                                         NaN
#
#                                OpSysPersonal use  \
# 11     Windows;Windows Subsystem for Linux (WSL)
# 36                                        Ubuntu
# 43     Windows;Windows Subsystem for Linux (WSL)
# 51     Windows;Windows Subsystem for Linux (WSL)
# 60                                        Ubuntu
# ...                                          ...
# 65375                                        NaN
# 65402                                        NaN
# 65404                                    Windows
# 65405                                        NaN
# 65432                                        NaN
#
#                            OpSysProfessional use  \
# 11     Windows;Windows Subsystem for Linux (WSL)
# 36                                        Ubuntu
# 43     Windows;Windows Subsystem for Linux (WSL)
# 51     Windows;Windows Subsystem for Linux (WSL)
# 60                                        Ubuntu
# ...                                          ...
# 65375                                        NaN
# 65402                                        NaN
# 65404                                      MacOS
# 65405                                        NaN
# 65432                                        NaN
#
#                           OfficeStackAsyncHaveWorkedWith  \
# 11                                                   NaN
# 36     Airtable;GitHub Discussions;Markdown File;Obsi...
# 43                         Jira;Markdown File;Miro;Wikis
# 51          Azure Devops;Clickup;Lucid;Microsoft Planner
# 60                                                  Jira
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404              Clickup;Markdown File;Notion;Obsidian
# 65405                                                NaN
# 65432                                                NaN
#
#                   OfficeStackAsyncWantToWorkWith  \
# 11                                           NaN
# 36     GitHub Discussions;Markdown File;Obsidian
# 43                 Jira;Markdown File;Miro;Wikis
# 51           Azure Devops;Clickup;Lucid;Obsidian
# 60                                           NaN
# ...                                          ...
# 65375                                        NaN
# 65402                                        NaN
# 65404                     Markdown File;Obsidian
# 65405                                        NaN
# 65432                                        NaN
#
#                          OfficeStackAsyncAdmired  \
# 11                                           NaN
# 36     GitHub Discussions;Markdown File;Obsidian
# 43                 Jira;Markdown File;Miro;Wikis
# 51                    Azure Devops;Clickup;Lucid
# 60                                           NaN
# ...                                          ...
# 65375                                        NaN
# 65402                                        NaN
# 65404                     Markdown File;Obsidian
# 65405                                        NaN
# 65432                                        NaN
#
#                            OfficeStackSyncHaveWorkedWith  \
# 11                                       Microsoft Teams
# 36                                 Discord;Whatsapp;Zoom
# 43                 Discord;Microsoft Teams;Whatsapp;Zoom
# 51                          Discord;Microsoft Teams;Zoom
# 60     Discord;Google Meet;Jitsi;Microsoft Teams;Slac...
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                Microsoft Teams;Slack;Whatsapp;Zoom
# 65405                                                NaN
# 65432                                                NaN
#
#           OfficeStackSyncWantToWorkWith            OfficeStackSyncAdmired  \
# 11                      Microsoft Teams                   Microsoft Teams
# 36                         Discord;Zoom                      Discord;Zoom
# 43     Discord;Microsoft Teams;Whatsapp  Discord;Microsoft Teams;Whatsapp
# 51                 Discord;Signal;Slack                           Discord
# 60                       Jitsi;Telegram                    Jitsi;Telegram
# ...                                 ...                               ...
# 65375                               NaN                               NaN
# 65402                               NaN                               NaN
# 65404                        Slack;Zoom                        Slack;Zoom
# 65405                               NaN                               NaN
# 65432                               NaN                               NaN
#
#                                AISearchDevHaveWorkedWith  \
# 11                                                   NaN
# 36                                                   NaN
# 43      ChatGPT;GitHub Copilot;Visual Studio Intellicode
# 51     Bing AI;ChatGPT;GitHub Copilot;Google Gemini;V...
# 60                  ChatGPT;GitHub Copilot;Google Gemini
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404         ChatGPT;Claude;GitHub Copilot;WolframAlpha
# 65405                                                NaN
# 65432                                                NaN
#
#                                AISearchDevWantToWorkWith  \
# 11                                                   NaN
# 36                                                   NaN
# 43                     ChatGPT;Visual Studio Intellicode
# 51     ChatGPT;GitHub Copilot;Google Gemini;Visual St...
# 60                                               ChatGPT
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                        ChatGPT;Claude;WolframAlpha
# 65405                                                NaN
# 65432                                                NaN
#
#                                       AISearchDevAdmired  \
# 11                                                   NaN
# 36                                                   NaN
# 43                     ChatGPT;Visual Studio Intellicode
# 51     ChatGPT;GitHub Copilot;Google Gemini;Visual St...
# 60                                               ChatGPT
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                        ChatGPT;Claude;WolframAlpha
# 65405                                                NaN
# 65432                                                NaN
#
#                                               NEWSOSites  \
# 11                         Stack Overflow;Stack Exchange
# 36     Stack Overflow for Teams (private knowledge sh...
# 43                         Stack Overflow;Stack Exchange
# 51                         Stack Overflow;Stack Exchange
# 60     Stack Overflow for Teams (private knowledge sh...
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                      Stack Overflow;Stack Exchange
# 65405                                                NaN
# 65432                                                NaN
#
#                            SOVisitFreq                SOAccount  \
# 11              Multiple times per day                      Yes
# 36              Multiple times per day                      Yes
# 43              Multiple times per day                      Yes
# 51     A few times per month or weekly                      Yes
# 60               Daily or almost daily                      Yes
# ...                                ...                      ...
# 65375                              NaN                      NaN
# 65402                              NaN                      NaN
# 65404  A few times per month or weekly  Not sure/can't remember
# 65405                              NaN                      NaN
# 65432                              NaN                      NaN
#
#                                 SOPartFreq  \
# 11                  Multiple times per day
# 36                  Multiple times per day
# 43                  Multiple times per day
# 51     Less than once per month or monthly
# 60         A few times per month or weekly
# ...                                    ...
# 65375                                  NaN
# 65402                                  NaN
# 65404                                  NaN
# 65405                                  NaN
# 65432                                  NaN
#
#                                                    SOHow           SOComm  \
# 11     Quickly finding code solutions;Engage with com...  Yes, definitely
# 36     Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 43     Quickly finding code solutions;Engage with com...  Yes, definitely
# 51     Quickly finding code solutions;Finding reliabl...          Neutral
# 60                        Quickly finding code solutions          Neutral
# ...                                                  ...              ...
# 65375                                                NaN              NaN
# 65402                                                NaN              NaN
# 65404                     Quickly finding code solutions   No, not really
# 65405                                                NaN              NaN
# 65432                                                NaN              NaN
#
#                       AISelect     AISent  \
# 11     No, and I don't plan to        NaN
# 36     No, and I don't plan to        NaN
# 43     No, and I don't plan to        NaN
# 51                         Yes  Favorable
# 60                         Yes  Favorable
# ...                        ...        ...
# 65375                      NaN        NaN
# 65402                      NaN        NaN
# 65404                      NaN        NaN
# 65405                      NaN        NaN
# 65432                      Yes  Favorable
#
#                                                    AIBen  \
# 11                                                   NaN
# 36                                                   NaN
# 43                                                   NaN
# 51     Increase productivity;Greater efficiency;Speed...
# 60                                    Greater efficiency
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432  Increase productivity;Greater efficiency;Speed...
#
#                             AIAcc  \
# 11                            NaN
# 36                            NaN
# 43                            NaN
# 51              Somewhat distrust
# 60              Somewhat distrust
# ...                           ...
# 65375                         NaN
# 65402                         NaN
# 65404                         NaN
# 65405                         NaN
# 65432  Neither trust nor distrust
#
#                                            AIComplex  \
# 11                                               NaN
# 36                                               NaN
# 43                                               NaN
# 51               Very poor at handling complex tasks
# 60               Very poor at handling complex tasks
# ...                                              ...
# 65375                                            NaN
# 65402                                            NaN
# 65404                                            NaN
# 65405                                            NaN
# 65432  Good, but not great at handling complex tasks
#
#                                    AIToolCurrently Using  \
# 11                                                   NaN
# 36                                                   NaN
# 43                                                   NaN
# 51     Learning about a codebase;Writing code;Documen...
# 60     Writing code;Debugging and getting help;Search...
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432  Learning about a codebase;Project planning;Wri...
#
#                                AIToolInterested in Using  \
# 11                                                   NaN
# 36                                                   NaN
# 43                                                   NaN
# 51                                                   NaN
# 60                                      Documenting code
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432  Debugging and getting help;Testing code;Deploy...
#
#                            AIToolNot interested in Using  \
# 11                                                   NaN
# 36                                                   NaN
# 43                                                   NaN
# 51                                      Project planning
# 60     Learning about a codebase;Project planning;Com...
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432                      Committing and reviewing code
#
#                               AINextMuch more integrated  \
# 11                                                   NaN
# 36                                                   NaN
# 43                                                   NaN
# 51                                                   NaN
# 60     Writing code;Debugging and getting help;Search...
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432  Writing code;Search for answers;Generating con...
#
#             AINextNo change  \
# 11                      NaN
# 36                      NaN
# 43                      NaN
# 51     Predictive analytics
# 60                      NaN
# ...                     ...
# 65375                   NaN
# 65402                   NaN
# 65404                   NaN
# 65405                   NaN
# 65432                   NaN
#
#                                    AINextMore integrated  \
# 11                                                   NaN
# 36                                                   NaN
# 43                                                   NaN
# 51     Learning about a codebase;Writing code;Documen...
# 60                                                   NaN
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432  Learning about a codebase;Project planning;Doc...
#
#       AINextLess integrated AINextMuch less integrated AIThreat  \
# 11                      NaN                        NaN      NaN
# 36                      NaN                        NaN      NaN
# 43                      NaN                        NaN      NaN
# 51                      NaN                        NaN       No
# 60                      NaN                        NaN       No
# ...                     ...                        ...      ...
# 65375                   NaN                        NaN      NaN
# 65402                   NaN                        NaN      NaN
# 65404                   NaN                        NaN      NaN
# 65405                   NaN                        NaN      NaN
# 65432                   NaN                        NaN       No
#
#                                                 AIEthics  \
# 11                                                   NaN
# 36                                                   NaN
# 43                                                   NaN
# 51     Missing or incorrect attribution for sources o...
# 60     Circulating misinformation or disinformation;M...
# ...                                                  ...
# 65375                                                NaN
# 65402                                                NaN
# 65404                                                NaN
# 65405                                                NaN
# 65432       Circulating misinformation or disinformation
#
#                                             AIChallenges TBranch  \
# 11                                                   NaN      No
# 36                                                   NaN     NaN
# 43                                                   NaN     Yes
# 51     Don’t trust the output or answers;Lack of exec...     NaN
# 60                     Don’t trust the output or answers     NaN
# ...                                                  ...     ...
# 65375                                                NaN     NaN
# 65402                                                NaN     NaN
# 65404                                                NaN     NaN
# 65405                                                NaN     NaN
# 65432  AI tools lack context of codebase,  internal a...     NaN
#
#                        ICorPM  WorkExp     Knowledge_1 Knowledge_2  \
# 11                        NaN      NaN             NaN         NaN
# 36                        NaN      NaN             NaN         NaN
# 43     Individual contributor     14.0  Strongly agree    Disagree
# 51                        NaN      NaN             NaN         NaN
# 60                        NaN      NaN             NaN         NaN
# ...                       ...      ...             ...         ...
# 65375                     NaN      NaN             NaN         NaN
# 65402                     NaN      NaN             NaN         NaN
# 65404                     NaN      NaN             NaN         NaN
# 65405                     NaN      NaN             NaN         NaN
# 65432                     NaN      NaN             NaN         NaN
#
#       Knowledge_3     Knowledge_4     Knowledge_5 Knowledge_6 Knowledge_7  \
# 11            NaN             NaN             NaN         NaN         NaN
# 36            NaN             NaN             NaN         NaN         NaN
# 43          Agree  Strongly agree  Strongly agree    Disagree       Agree
# 51            NaN             NaN             NaN         NaN         NaN
# 60            NaN             NaN             NaN         NaN         NaN
# ...           ...             ...             ...         ...         ...
# 65375         NaN             NaN             NaN         NaN         NaN
# 65402         NaN             NaN             NaN         NaN         NaN
# 65404         NaN             NaN             NaN         NaN         NaN
# 65405         NaN             NaN             NaN         NaN         NaN
# 65432         NaN             NaN             NaN         NaN         NaN
#
#       Knowledge_8     Knowledge_9        Frequency_1       Frequency_2  \
# 11            NaN             NaN                NaN               NaN
# 36            NaN             NaN                NaN               NaN
# 43       Disagree  Strongly agree  6-10 times a week  10+ times a week
# 51            NaN             NaN                NaN               NaN
# 60            NaN             NaN                NaN               NaN
# ...           ...             ...                ...               ...
# 65375         NaN             NaN                NaN               NaN
# 65402         NaN             NaN                NaN               NaN
# 65404         NaN             NaN                NaN               NaN
# 65405         NaN             NaN                NaN               NaN
# 65432         NaN             NaN                NaN               NaN
#
#       Frequency_3         TimeSearching           TimeAnswering  \
# 11            NaN                   NaN                     NaN
# 36            NaN                   NaN                     NaN
# 43          Never  60-120 minutes a day  Over 120 minutes a day
# 51            NaN                   NaN                     NaN
# 60            NaN                   NaN                     NaN
# ...           ...                   ...                     ...
# 65375         NaN                   NaN                     NaN
# 65402         NaN                   NaN                     NaN
# 65404         NaN                   NaN                     NaN
# 65405         NaN                   NaN                     NaN
# 65432         NaN                   NaN                     NaN
#
#                     Frustration  \
# 11                          NaN
# 36                          NaN
# 43     Amount of technical debt
# 51                          NaN
# 60                          NaN
# ...                         ...
# 65375                       NaN
# 65402                       NaN
# 65404                       NaN
# 65405                       NaN
# 65432                       NaN
#
#                                         ProfessionalTech ProfessionalCloud  \
# 11                                                   NaN               NaN
# 36                                                   NaN               NaN
# 43     Automated testing;AI-assisted technology tool(...               NaN
# 51                                                   NaN               NaN
# 60                                                   NaN               NaN
# ...                                                  ...               ...
# 65375                                                NaN               NaN
# 65402                                                NaN               NaN
# 65404                                                NaN               NaN
# 65405                                                NaN               NaN
# 65432                                                NaN               NaN
#
#                    ProfessionalQuestion          Industry  JobSatPoints_1  \
# 11                                  NaN               NaN             NaN
# 36                                  NaN               NaN             NaN
# 43     Traditional public search engine  Higher Education             0.0
# 51                                  NaN               NaN             NaN
# 60                                  NaN               NaN             NaN
# ...                                 ...               ...             ...
# 65375                               NaN               NaN             NaN
# 65402                               NaN               NaN             NaN
# 65404                               NaN               NaN             NaN
# 65405                               NaN               NaN             NaN
# 65432                               NaN               NaN             NaN
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# 11                NaN             NaN             NaN             NaN
# 36                NaN             NaN             NaN             NaN
# 43                0.0             0.0            30.0            10.0
# 51                NaN             NaN             NaN             NaN
# 60                NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 65375             NaN             NaN             NaN             NaN
# 65402             NaN             NaN             NaN             NaN
# 65404             NaN             NaN             NaN             NaN
# 65405             NaN             NaN             NaN             NaN
# 65432             NaN             NaN             NaN             NaN
#
#        JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# 11                NaN             NaN              NaN              NaN
# 36                NaN             NaN              NaN              NaN
# 43               20.0            30.0             10.0              0.0
# 51                NaN             NaN              NaN              NaN
# 60                NaN             NaN              NaN              NaN
# ...               ...             ...              ...              ...
# 65375             NaN             NaN              NaN              NaN
# 65402             NaN             NaN              NaN              NaN
# 65404             NaN             NaN              NaN              NaN
# 65405             NaN             NaN              NaN              NaN
# 65432             NaN             NaN              NaN              NaN
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly  \
# 11     Appropriate in length  Neither easy nor difficult                  NaN
# 36     Appropriate in length                        Easy                  NaN
# 43     Appropriate in length                        Easy                  NaN
# 51     Appropriate in length                        Easy                  NaN
# 60                  Too long  Neither easy nor difficult                  NaN
# ...                      ...                         ...                  ...
# 65375                    NaN                         NaN                  NaN
# 65402                    NaN                         NaN                  NaN
# 65404                    NaN                         NaN                  NaN
# 65405                    NaN                         NaN                  NaN
# 65432                    NaN                         NaN                  NaN
#
#        JobSat
# 11        NaN
# 36        NaN
# 43        9.0
# 51        NaN
# 60        NaN
# ...       ...
# 65375     NaN
# 65402     NaN
# 65404     NaN
# 65405     NaN
# 65432     NaN
#
# [7069 rows x 114 columns]
